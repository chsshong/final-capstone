# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest as ztest
from statsmodels.stats.proportion import proportions_ztest
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/2001-2019-National-Data-Age.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Year                                       95 non-null     int64
#  1   Age Group                                  95 non-null     object
#  2   Veteran Suicide Deaths                     95 non-null     int64
#  3   Veteran Population Estimate                95 non-null     int64
#  4   Veteran Crude Rate per 100,000             95 non-null     float64
#  5   Non-Veteran Suicide Deaths                 95 non-null     int64
#  6   Non-Veteran Population Estimate            95 non-null     int64
#  7   Non-Veteran Crude Rate per 100,000         95 non-null     float64
#  8   Male Veteran Suicide Deaths                95 non-null     int64
#  9   Male Veteran Population Estimate           95 non-null     int64
#  10  Male Veteran Crude Rate per 100,000        95 non-null     float64
#  11  Male Non-Veteran Suicide Deaths            95 non-null     int64
#  12  Male Non-Veteran Population Estimate       95 non-null     int64
#  13  Male Non-Veteran Crude Rate per 100,000    95 non-null     float64
#  14  Age Group 2                                76 non-null     object
#  15  Female Veteran Suicide Deaths              76 non-null     float64
#  16  Female Veteran Population Estimate         76 non-null     float64
#  17  Female Veteran Crude Rate per 100,000      76 non-null     float64
#  18  Female Non-Veteran Suicide Deaths          76 non-null     float64
#  19  Female Non-Veteran Population Estimate     76 non-null     float64
#  20  Female Non-Veteran Crude Rate per 100,000  76 non-null     float64
# dtypes: float64(10), int64(9), object(2)
# memory usage: 15.7+ KB

# %%
df.head()
# Out:
#    Year Age Group  Veteran Suicide Deaths  Veteran Population Estimate  \
# 0  2001     18-34                     618                      2616000
# 1  2001     35-54                    2505                      8899000
# 2  2001     55-74                    1689                      9761000
# 3  2001       75+                    1174                      4457000
# 4  2001     Total                    5989                     25733000
#
#    Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# 0                            23.6                        7675
# 1                            28.1                       10072
# 2                            17.3                        4060
# 3                            26.3                        1787
# 4                            23.3                       23591
#
#    Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# 0                         64848174                                11.8
# 1                         75539020                                13.3
# 2                         33728474                                12.0
# 3                         12449112                                14.4
# 4                        186564780                                12.6
#
#    Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# 0                          588                           2223000
# 1                         2398                           8137000
# 2                         1678                           9512000
# 3                         1168                           4240000
# 4                         5835                          24112000
#
#    Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# 0                                 26.5                             6426
# 1                                 29.5                             7286
# 2                                 17.6                             2925
# 3                                 27.5                             1381
# 4                                 24.2                            18015
#
#    Male Non-Veteran Population Estimate  \
# 0                              32015909
# 1                              33611510
# 2                              10890782
# 3                               2024949
# 4                              78543150
#
#    Male Non-Veteran Crude Rate per 100,000 Age Group 2  \
# 0                                     20.1       18-34
# 1                                     21.7       35-54
# 2                                     26.9         55+
# 3                                     68.2         NaN
# 4                                     22.9       Total
#
#    Female Veteran Suicide Deaths  Female Veteran Population Estimate  \
# 0                           30.0                            393000.0
# 1                          107.0                            762000.0
# 2                           17.0                            466000.0
# 3                            NaN                                 NaN
# 4                          154.0                           1621000.0
#
#    Female Veteran Crude Rate per 100,000  Female Non-Veteran Suicide Deaths  \
# 0                                    7.6                             1249.0
# 1                                   14.0                             2786.0
# 2                                    3.6                             1541.0
# 3                                    NaN                                NaN
# 4                                    9.5                             5576.0
#
#    Female Non-Veteran Population Estimate  \
# 0                              32832265.0
# 1                              41927510.0
# 2                              33261855.0
# 3                                     NaN
# 4                             108021630.0
#
#    Female Non-Veteran Crude Rate per 100,000
# 0                                        3.8
# 1                                        6.6
# 2                                        4.6
# 3                                        NaN
# 4                                        5.2

# %%
df.describe()
# Out:
#               Year  Veteran Suicide Deaths  Veteran Population Estimate  \
# count    95.000000               95.000000                 9.500000e+01
# mean   2010.000000             2542.031579                 9.120863e+06
# std       5.506283             2003.929684                 7.328383e+06
# min    2001.000000              531.000000                 1.863000e+06
# 25%    2005.000000             1340.500000                 4.558500e+06
# 50%    2010.000000             1868.000000                 6.627000e+06
# 75%    2015.000000             2465.500000                 9.677000e+06
# max    2019.000000             6761.000000                 2.573300e+07
#
#        Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# count                       95.000000                   95.000000
# mean                        29.124211                12432.957895
# std                          5.350536                10390.102289
# min                         17.300000                 1428.000000
# 25%                         25.950000                 4735.500000
# 50%                         28.900000                 9718.000000
# 75%                         30.950000                13736.500000
# max                         47.700000                39850.000000
#
#        Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# count                     9.500000e+01                           95.000000
# mean                      8.469766e+07                           14.296842
# std                       6.809825e+07                            1.967905
# min                       1.244911e+07                           10.600000
# 25%                       4.061417e+07                           12.800000
# 50%                       6.987119e+07                           14.100000
# 75%                       7.903249e+07                           16.000000
# max                       2.354034e+08                           18.200000
#
#        Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# count                    95.000000                      9.500000e+01
# mean                   2447.568421                      8.391832e+06
# std                    1930.093933                      6.801922e+06
# min                     498.000000                      1.514000e+06
# 25%                    1330.500000                      4.380500e+06
# 50%                    1798.000000                      5.781000e+06
# 75%                    2376.000000                      9.360000e+06
# max                    6384.000000                      2.411200e+07
#
#        Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# count                            95.000000                        95.000000
# mean                             31.062105                      9340.684211
# std                               6.472038                      7790.829111
# min                              17.600000                      1045.000000
# 25%                              27.650000                      3306.500000
# 50%                              30.500000                      7575.000000
# 75%                              32.950000                      9927.000000
# max                              53.100000                     30146.000000
#
#        Male Non-Veteran Population Estimate  \
# count                          9.500000e+01
# mean                           3.716786e+07
# std                            3.088360e+07
# min                            1.999122e+06
# 25%                            1.449333e+07
# 50%                            3.414778e+07
# 75%                            3.673595e+07
# max                            1.065437e+08
#
#        Male Non-Veteran Crude Rate per 100,000  Female Veteran Suicide Deaths  \
# count                                95.000000                      76.000000
# mean                                 29.970526                     118.078947
# std                                  11.650239                      84.667942
# min                                  19.600000                      17.000000
# 25%                                  22.900000                      53.500000
# 50%                                  26.100000                     107.000000
# 75%                                  28.300000                     151.250000
# max                                  68.500000                     377.000000
#
#        Female Veteran Population Estimate  \
# count                        7.600000e+01
# mean                         9.112895e+05
# std                          5.566310e+05
# min                          3.490000e+05
# 25%                          4.517500e+05
# 50%                          7.875000e+05
# 75%                          1.048750e+06
# max                          1.992000e+06
#
#        Female Veteran Crude Rate per 100,000  \
# count                              76.000000
# mean                               12.628947
# std                                 4.317092
# min                                 3.600000
# 25%                                 9.675000
# 50%                                13.100000
# 75%                                15.400000
# max                                24.100000
#
#        Female Non-Veteran Suicide Deaths  \
# count                          76.000000
# mean                         3865.342105
# std                          2466.236580
# min                          1249.000000
# 25%                          2013.750000
# 50%                          3272.500000
# 75%                          4319.750000
# max                          9722.000000
#
#        Female Non-Veteran Population Estimate  \
# count                            7.600000e+01
# mean                             5.941224e+07
# std                              3.492196e+07
# min                              3.283226e+07
# 25%                              3.653192e+07
# 50%                              4.199917e+07
# 75%                              6.533588e+07
# max                              1.288597e+08
#
#        Female Non-Veteran Crude Rate per 100,000
# count                                  76.000000
# mean                                    6.402632
# std                                     1.498975
# min                                     3.800000
# 25%                                     5.300000
# 50%                                     6.350000
# 75%                                     7.350000
# max                                     9.400000

# %%
df = df[df['Age Group'] != 'Total']

# %%
df['Veteran Population Estimate in millions'] = df['Veteran Population Estimate']/1000000

# %%
df.head()
# Out:
#    Year Age Group  Veteran Suicide Deaths  Veteran Population Estimate  \
# 0  2001     18-34                     618                      2616000
# 1  2001     35-54                    2505                      8899000
# 2  2001     55-74                    1689                      9761000
# 3  2001       75+                    1174                      4457000
# 5  2002     18-34                     589                      2504000
#
#    Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# 0                            23.6                        7675
# 1                            28.1                       10072
# 2                            17.3                        4060
# 3                            26.3                        1787
# 5                            23.5                        7757
#
#    Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# 0                         64848174                                11.8
# 1                         75539020                                13.3
# 2                         33728474                                12.0
# 3                         12449112                                14.4
# 5                         65326354                                11.9
#
#    Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# 0                          588                           2223000
# 1                         2398                           8137000
# 2                         1678                           9512000
# 3                         1168                           4240000
# 5                          565                           2112000
#
#    Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# 0                                 26.5                             6426
# 1                                 29.5                             7286
# 2                                 17.6                             2925
# 3                                 27.5                             1381
# 5                                 26.8                             6440
#
#    Male Non-Veteran Population Estimate  \
# 0                              32015909
# 1                              33611510
# 2                              10890782
# 3                               2024949
# 5                              32309265
#
#    Male Non-Veteran Crude Rate per 100,000 Age Group 2  \
# 0                                     20.1       18-34
# 1                                     21.7       35-54
# 2                                     26.9         55+
# 3                                     68.2         NaN
# 5                                     19.9       18-34
#
#    Female Veteran Suicide Deaths  Female Veteran Population Estimate  \
# 0                           30.0                            393000.0
# 1                          107.0                            762000.0
# 2                           17.0                            466000.0
# 3                            NaN                                 NaN
# 5                           24.0                            392000.0
#
#    Female Veteran Crude Rate per 100,000  Female Non-Veteran Suicide Deaths  \
# 0                                    7.6                             1249.0
# 1                                   14.0                             2786.0
# 2                                    3.6                             1541.0
# 3                                    NaN                                NaN
# 5                                    6.1                             1317.0
#
#    Female Non-Veteran Population Estimate  \
# 0                              32832265.0
# 1                              41927510.0
# 2                              33261855.0
# 3                                     NaN
# 5                              33017089.0
#
#    Female Non-Veteran Crude Rate per 100,000  \
# 0                                        3.8
# 1                                        6.6
# 2                                        4.6
# 3                                        NaN
# 5                                        4.0
#
#    Veteran Population Estimate in millions
# 0                                    2.616
# 1                                    8.899
# 2                                    9.761
# 3                                    4.457
# 5                                    2.504

# %%
df_18_34 = df[df['Age Group'] == '18-34']
df_35_54 = df[df['Age Group'] == '35-54']
df_55_74 = df[df['Age Group'] == '55-74']
df_75 = df[df['Age Group'] == '75+']

# %%
fig, ax = plt.subplots(figsize = (10,8), dpi=200)
sns.lineplot(x= df_18_34['Year'], y= df_18_34['Veteran Population Estimate in millions'], marker='o', label = '18-34')
sns.lineplot(x= df_35_54['Year'], y= df_35_54['Veteran Population Estimate in millions'], marker='o', label = '35-54')
sns.lineplot(x= df_55_74['Year'], y= df_55_74['Veteran Population Estimate in millions'], marker='o', label = '55-74')
sns.lineplot(x= df_75['Year'], y= df_75['Veteran Population Estimate in millions'], marker='o', label = '75+')
ax.set_title('Veteran Population by Age Cohort',  fontsize = 25)
ax.set_xticks(df['Year'])
ax.set_xlabel('Year', fontsize = 15)
ax.set_ylabel('Number of Veterans in millions', fontsize = 15)
ax.set_yticks(np.arange(0, 11, 1))
plt.yticks(fontsize = 10)
plt.legend()
fig.tight_layout()
#plt.savefig('1.jpg', bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize = (10,8), dpi=200)
sns.lineplot(x= df_18_34['Year'], y= df_18_34['Veteran Suicide Deaths'], marker='o', label = '18-34')
sns.lineplot(x= df_35_54['Year'], y= df_35_54['Veteran Suicide Deaths'], marker='o', label = '35-54')
sns.lineplot(x= df_55_74['Year'], y= df_55_74['Veteran Suicide Deaths'], marker='o', label = '55-74')
sns.lineplot(x= df_75['Year'], y= df_75['Veteran Suicide Deaths'], marker='o', label = '75+')
ax.set_title('Veteran Suicide Deaths by Age Cohort', fontsize = 25)
ax.set_xticks(df['Year'])
ax.set_xlabel('Year', fontsize = 15)
ax.set_ylabel('Suicide Deaths', fontsize = 15)
ax.set_yticks(np.arange(0, 3000, 250))
plt.yticks(fontsize = 10)
plt.legend()
fig.tight_layout()
#plt.savefig('1.jpg', bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize = (12,8), dpi=200)
sns.lineplot(x= df_18_34['Year'], y= df_18_34['Male Veteran Crude Rate per 100,000'], marker='o', label = '18-34')
sns.lineplot(x= df_35_54['Year'], y= df_35_54['Male Veteran Crude Rate per 100,000'], marker='o', label = '35-54')
sns.lineplot(x= df_55_74['Year'], y= df_55_74['Male Veteran Crude Rate per 100,000'], marker='o', label = '55-74')
sns.lineplot(x= df_75['Year'], y= df_75['Male Veteran Crude Rate per 100,000'], marker='o', label = '75+')
plt.title('Male Veteran Suicide Rate by Age Cohort', fontsize = 20)
plt.xticks(df['Year'])
ax.set_yticks(np.arange(0, 60, 5))
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Suicide rate per 100,000', fontsize = 15)
plt.legend()
#plt.savefig('1.jpg', bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,10))
sns.lineplot(x= df_18_34['Year'], y= df_18_34['Male Veteran Crude Rate per 100,000'], marker='o', label = '18-34')
sns.lineplot(x= df_35_54['Year'], y= df_35_54['Male Veteran Crude Rate per 100,000'], marker='o', label = '35-54')
sns.lineplot(x= df_55_74['Year'], y= df_55_74['Male Veteran Crude Rate per 100,000'], marker='o', label = '55-74')
sns.lineplot(x= df_75['Year'], y= df_75['Male Veteran Crude Rate per 100,000'], marker='o', label = '75+')
plt.title('Male Veteran Suicide Rate by Age Cohort', fontsize = 20)
plt.xticks(df['Year'])
ax.set_yticks(np.arange(0, 60, 5))
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Suicide rate per 100,000', fontsize = 15)
plt.legend()
#plt.savefig('1.jpg', bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,10))
sns.lineplot(x= df_18_34['Year'], y= df_18_34['Female Veteran Crude Rate per 100,000'], marker='o', label = '18-34')
sns.lineplot(x= df_35_54['Year'], y= df_35_54['Female Veteran Crude Rate per 100,000'], marker='o', label = '35-54')
sns.lineplot(x= df_55_74['Year'], y= df_55_74['Female Veteran Crude Rate per 100,000'], marker='o', label = '55-74')
sns.lineplot(x= df_75['Year'], y= df_75['Female Veteran Crude Rate per 100,000'], marker='o', label = '75+')
plt.title('Female Veteran Suicide Rate by Age Cohort', fontsize = 20)
plt.xticks(df['Year'])
ax.set_yticks(np.arange(0, 27, 2))
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Suicide rate per 100,000', fontsize = 15)
plt.legend()
#plt.savefig('1.jpg', bbox_inches="tight")
plt.show()

# %%
#df.groupby(['Age Group', 'Year']).sum()

# %%
df_2019 = df[df['Year'] == 2019]

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 90 to 93
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Year                                       4 non-null      int64
#  1   Age Group                                  4 non-null      object
#  2   Veteran Suicide Deaths                     4 non-null      int64
#  3   Veteran Population Estimate                4 non-null      int64
#  4   Veteran Crude Rate per 100,000             4 non-null      float64
#  5   Non-Veteran Suicide Deaths                 4 non-null      int64
#  6   Non-Veteran Population Estimate            4 non-null      int64
#  7   Non-Veteran Crude Rate per 100,000         4 non-null      float64
#  8   Male Veteran Suicide Deaths                4 non-null      int64
#  9   Male Veteran Population Estimate           4 non-null      int64
#  10  Male Veteran Crude Rate per 100,000        4 non-null      float64
#  11  Male Non-Veteran Suicide Deaths            4 non-null      int64
#  12  Male Non-Veteran Population Estimate       4 non-null      int64
#  13  Male Non-Veteran Crude Rate per 100,000    4 non-null      float64
#  14  Age Group 2                                3 non-null      object
#  15  Female Veteran Suicide Deaths              3 non-null      float64
#  16  Female Veteran Population Estimate         3 non-null      float64
#  17  Female Veteran Crude Rate per 100,000      3 non-null      float64
#  18  Female Non-Veteran Suicide Deaths          3 non-null      float64
#  19  Female Non-Veteran Population Estimate     3 non-null      float64
#  20  Female Non-Veteran Crude Rate per 100,000  3 non-null      float64
#  21  Veteran Population Estimate in millions    4 non-null      float64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 736.0+ bytes

# %% [markdown]
# Testing with 2019 data

# %% [markdown]
# ### Test 4.1
# #### H0: VA age 18-34 <= 35-54
# #### Ha: VA age 18-34 > 35-54

# %%
df_2019.head()
# Out:
#     Year Age Group  Veteran Suicide Deaths  Veteran Population Estimate  \
# 90  2019     18-34                     828                      1863000
# 91  2019     35-54                    1663                      5075000
# 92  2019     55-74                    2407                      8352000
# 93  2019       75+                    1336                      4507000
#
#     Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# 90                            44.4                       12085
# 91                            32.8                       13874
# 92                            28.8                       10698
# 93                            29.6                        2970
#
#     Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# 90                         74296527                                16.3
# 91                         77459046                                17.9
# 92                         65579970                                16.3
# 93                         18067830                                16.4
#
#     Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# 90                          766                           1514000
# 91                         1525                           4258000
# 92                         2317                           7669000
# 93                         1329                           4364000
#
#     Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# 90                                 50.6                             9763
# 91                                 35.8                            10146
# 92                                 30.2                             7855
# 93                                 30.5                             2409
#
#     Male Non-Veteran Population Estimate  \
# 90                              37297101
# 91                              36706046
# 92                              27529798
# 93                               5010711
#
#     Male Non-Veteran Crude Rate per 100,000 Age Group 2  \
# 90                                     26.2       18-34
# 91                                     27.6       35-54
# 92                                     28.5         55+
# 93                                     48.1         NaN
#
#     Female Veteran Suicide Deaths  Female Veteran Population Estimate  \
# 90                           62.0                            349000.0
# 91                          138.0                            817000.0
# 92                           97.0                            826000.0
# 93                            NaN                                 NaN
#
#     Female Veteran Crude Rate per 100,000  Female Non-Veteran Suicide Deaths  \
# 90                                   17.8                             2322.0
# 91                                   16.9                             3728.0
# 92                                   11.7                             3404.0
# 93                                    NaN                                NaN
#
#     Female Non-Veteran Population Estimate  \
# 90                              36999426.0
# 91                              40753000.0
# 92                              51107291.0
# 93                                     NaN
#
#     Female Non-Veteran Crude Rate per 100,000  \
# 90                                        6.3
# 91                                        9.1
# 92                                        6.7
# 93                                        NaN
#
#     Veteran Population Estimate in millions
# 90                                    1.863
# 91                                    5.075
# 92                                    8.352
# 93                                    4.507

# %%
shared_sample_freq = (828 + 1663) / 6938000
shared_sample_variance = 6938000 * (shared_sample_freq * (1 - shared_sample_freq)) / (1863000 * 5075000)

difference_in_proportions = stats.norm(0, np.sqrt(shared_sample_variance))

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

x = np.linspace(-1, 1, num=1000)
ax.plot(x, difference_in_proportions.pdf(x), linewidth=3)
ax.set_xlim(-1, 1)
ax.set_title("Distribution of Difference in Sample Frequencies Assuming $H_0$")
# Out:
# Text(0.5, 1.0, 'Distribution of Difference in Sample Frequencies Assuming $H_0$')

# %%
sample_18_34_freq = 828/1863000
sample_35_54_freq = 1663/5075000
difference_in_sample_proportions = sample_18_34_freq - sample_35_54_freq
print(difference_in_sample_proportions)
# Out:
# 0.00011675971538040506

# %%
p_value = 1 - difference_in_proportions.cdf(difference_in_sample_proportions)
print(p_value)
# Out:
# 3.1319391524675666e-13

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

x = np.linspace(-1, 1, num=250)
ax.plot(x, difference_in_proportions.pdf(x), linewidth=3)
ax.fill_between(x, difference_in_proportions.pdf(x), where=(x >= difference_in_sample_proportions),
                color="red", alpha=0.5)
ax.set_xlim(-1, 1)
ax.set_title("p-value Reigon")
# Out:
# Text(0.5, 1.0, 'p-value Reigon')

# %% [markdown]
# ### Test 4.2
# #### H0: VA age 18-34 <= 55-74
# #### Ha: VA age 18-34 > 55-74

# %%
df_2019.head()
# Out:
#     Year Age Group  Veteran Suicide Deaths  Veteran Population Estimate  \
# 90  2019     18-34                     828                      1863000
# 91  2019     35-54                    1663                      5075000
# 92  2019     55-74                    2407                      8352000
# 93  2019       75+                    1336                      4507000
#
#     Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# 90                            44.4                       12085
# 91                            32.8                       13874
# 92                            28.8                       10698
# 93                            29.6                        2970
#
#     Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# 90                         74296527                                16.3
# 91                         77459046                                17.9
# 92                         65579970                                16.3
# 93                         18067830                                16.4
#
#     Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# 90                          766                           1514000
# 91                         1525                           4258000
# 92                         2317                           7669000
# 93                         1329                           4364000
#
#     Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# 90                                 50.6                             9763
# 91                                 35.8                            10146
# 92                                 30.2                             7855
# 93                                 30.5                             2409
#
#     Male Non-Veteran Population Estimate  \
# 90                              37297101
# 91                              36706046
# 92                              27529798
# 93                               5010711
#
#     Male Non-Veteran Crude Rate per 100,000 Age Group 2  \
# 90                                     26.2       18-34
# 91                                     27.6       35-54
# 92                                     28.5         55+
# 93                                     48.1         NaN
#
#     Female Veteran Suicide Deaths  Female Veteran Population Estimate  \
# 90                           62.0                            349000.0
# 91                          138.0                            817000.0
# 92                           97.0                            826000.0
# 93                            NaN                                 NaN
#
#     Female Veteran Crude Rate per 100,000  Female Non-Veteran Suicide Deaths  \
# 90                                   17.8                             2322.0
# 91                                   16.9                             3728.0
# 92                                   11.7                             3404.0
# 93                                    NaN                                NaN
#
#     Female Non-Veteran Population Estimate  \
# 90                              36999426.0
# 91                              40753000.0
# 92                              51107291.0
# 93                                     NaN
#
#     Female Non-Veteran Crude Rate per 100,000  \
# 90                                        6.3
# 91                                        9.1
# 92                                        6.7
# 93                                        NaN
#
#     Veteran Population Estimate in millions
# 90                                    1.863
# 91                                    5.075
# 92                                    8.352
# 93                                    4.507

# %%
shared_sample_freq = (623 + 2049) / (2102000+6627000)
shared_sample_variance = (2102000+6627000) * (shared_sample_freq * (1 - shared_sample_freq)) / (2102000*6627000)

difference_in_proportions = stats.norm(0, np.sqrt(shared_sample_variance))

# %%
sample_18_34_freq = 828/1863000
sample_55_74_freq = 2407/8352000
difference_in_sample_proportions = sample_18_34_freq - sample_55_74_freq
print(difference_in_sample_proportions)
# Out:
# 0.00015625000000000003

# %%
p_value = 1 - difference_in_proportions.cdf(difference_in_sample_proportions)
print(p_value)
# Out:
# 0.0

# %% [markdown]
# Testing with median year

# %%
df_2010 = df[df['Year'] == 2010]

# %%
df_2010.head()
# Out:
#     Year Age Group  Veteran Suicide Deaths  Veteran Population Estimate  \
# 45  2010     18-34                     623                      2102000
# 46  2010     35-54                    2049                      6627000
# 47  2010     55-74                    2379                      9221000
# 48  2010       75+                    1481                      4802000
#
#     Veteran Crude Rate per 100,000  Non-Veteran Suicide Deaths  \
# 45                            29.6                        8977
# 46                            30.9                       13321
# 47                            25.8                        6979
# 48                            30.8                        1539
#
#     Non-Veteran Population Estimate  Non-Veteran Crude Rate per 100,000  \
# 45                         69871194                                12.8
# 46                         79339864                                16.8
# 47                         49418147                                14.1
# 48                         13819795                                11.1
#
#     Male Veteran Suicide Deaths  Male Veteran Population Estimate  \
# 45                          575                           1696000
# 46                         1919                           5781000
# 47                         2327                           8839000
# 48                         1479                           4651000
#
#     Male Veteran Crude Rate per 100,000  Male Non-Veteran Suicide Deaths  \
# 45                                 33.9                             7281
# 46                                 33.2                             9847
# 47                                 26.3                             4960
# 48                                 31.8                             1138
#
#     Male Non-Veteran Population Estimate  \
# 45                              34727956
# 46                              36744461
# 47                              19073851
# 48                               2652436
#
#     Male Non-Veteran Crude Rate per 100,000 Age Group 2  \
# 45                                     21.0       18-34
# 46                                     26.8       35-54
# 47                                     26.0         55+
# 48                                     42.9         NaN
#
#     Female Veteran Suicide Deaths  Female Veteran Population Estimate  \
# 45                           48.0                            406000.0
# 46                          130.0                            846000.0
# 47                           54.0                            533000.0
# 48                            NaN                                 NaN
#
#     Female Veteran Crude Rate per 100,000  Female Non-Veteran Suicide Deaths  \
# 45                                   11.8                             1696.0
# 46                                   15.4                             3474.0
# 47                                   10.1                             2420.0
# 48                                    NaN                                NaN
#
#     Female Non-Veteran Population Estimate  \
# 45                              35143238.0
# 46                              42595403.0
# 47                              41511655.0
# 48                                     NaN
#
#     Female Non-Veteran Crude Rate per 100,000  \
# 45                                        4.8
# 46                                        8.2
# 47                                        5.8
# 48                                        NaN
#
#     Veteran Population Estimate in millions
# 45                                    2.102
# 46                                    6.627
# 47                                    9.221
# 48                                    4.802

# %%
shared_sample_freq = (623 + 2049) / (2102000+6627000)
shared_sample_variance = (2102000+6627000) * (shared_sample_freq * (1 - shared_sample_freq)) / (2102000*6627000)

difference_in_proportions = stats.norm(0, np.sqrt(shared_sample_variance))

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

x = np.linspace(-1, 1, num=1000)
ax.plot(x, difference_in_proportions.pdf(x), linewidth=3)
ax.set_xlim(-1, 1)
ax.set_title("Distribution of Difference in Sample Frequencies Assuming $H_0$")
# Out:
# Text(0.5, 1.0, 'Distribution of Difference in Sample Frequencies Assuming $H_0$')

# %%
sample_18_34_freq = 623/2102000
sample_35_54_freq = 2049/6627000
difference_in_sample_proportions = sample_18_34_freq - sample_35_54_freq
print(difference_in_sample_proportions)
# Out:
# -1.2805282774085245e-05

# %%
p_value = 1 - difference_in_proportions.cdf(difference_in_sample_proportions)
print(p_value)
# Out:
# 0.8224453306526158

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

x = np.linspace(-1, 1, num=250)
ax.plot(x, difference_in_proportions.pdf(x), linewidth=3)
ax.fill_between(x, difference_in_proportions.pdf(x), where=(x >= difference_in_sample_proportions),
                color="red", alpha=0.5)
ax.set_xlim(-1, 1)
ax.set_title("p-value Reigon")
# Out:
# Text(0.5, 1.0, 'p-value Reigon')
